# %% [markdown]
# # Code to train and test

# %% [markdown]
# ### Write the captions from json file:

# %%
import json
import os, os.path
import pickle

train_val = json.load(open('videodatainfo_2017.json', 'r'))


# combine all images and annotations together
sentences = train_val['sentences']

# for efficiency lets group annotations by video
itoa = {}
for s in sentences:
    videoid_buf = s['video_id']
    videoid = int(videoid_buf[5:])
    if not videoid in itoa: itoa[videoid] = []
    itoa[videoid].append(s)
    
output = open('./DATA/word_features/captions.pkl', 'wb')
pickle.dump(itoa, output)
output.close()

# %% [markdown]
# ### Auxilary functions to handle captions

# %%
import numpy as np

"""Functions to do the following:
            * Create vocabulary
            * Create dictionary mapping from word to word_id
            * Map words in captions to word_ids"""

def build_vocab(word_count_thresh):
    """Function to create vocabulary based on word count threshold.
        Input:
                word_count_thresh: Threshold to choose words to include to the vocabulary
        Output:
                vocabulary: Set of words in the vocabulary"""
    
    pkl_file = open('./DATA/word_features/captions.pkl', 'rb')
    sentences = pickle.load(pkl_file)
    pkl_file.close()

    unk_required = False
    all_captions = []
    word_counts = {}
    for vid in sentences.keys():
        for cid in range(0,20):
            caption = sentences[vid][cid]['caption']
            caption = '<BOS> ' + caption + ' <EOS>'
            all_captions.append(caption)
            for word in caption.split(' '):
                if word in word_counts.keys():
                    word_counts[word] += 1
                else:
                    word_counts[word] = 1
    for word in word_counts.keys():
        if word_counts[word] < word_count_thresh:
            word_counts.pop(word)
            unk_required = True
    return word_counts,unk_required

def word_to_word_ids(word_counts,unk_required, vocab_size):
    """Function to map individual words to their id's.
        Input:
                word_counts: Dictionary with words mapped to their counts
        Output:
                word_to_id: Dictionary with words mapped to their id's. 
    """

    count = 0
    word_to_id = {}
    id_to_word = {}

    # Taking the most frequent vocab_size words
    words = [word for word in word_counts.keys()]
    values = [word_counts[word] for word in words]
    sorted_indices = np.argsort(values)
    words = np.array(words)
    most_freq_words = words[sorted_indices[::-1][0:vocab_size]]
    
    id_to_word = [most_freq_words[i] for i in range(most_freq_words.shape[0])] 
    
    #word2idx
    word_to_id = {}
    for i in range(len(id_to_word)):
        word_to_id[id_to_word[i]] = i
    
    print(word_to_id['<EOS>'])
    index = word_to_id['<EOS>']
    word = id_to_word[0]
    print(index,word)
    
    word_to_id['<EOS>'] = 0
    id_to_word[0] = '<EOS>'
    word_to_id[word] = index
    id_to_word[index] = word
    
    return word_to_id,id_to_word

def convert_caption(caption,word_to_id,max_caption_length):
    """Function to map each word in a caption to it's respective id and to retrieve caption masks
        Input:
                caption: Caption to convert to word_to_word_ids
                word_to_id: Dictionary mapping words to their respective id's
                max_caption_length: Maximum number of words allowed in a caption
        Output:
                caps: Captions with words mapped to word id's
                cap_masks: Caption masks with 1's at positions of words and 0's at pad locations"""
    caps,cap_masks = [],[]
    if type(caption) == 'str':
        caption = [caption] # if single caption, make it a list of captions of length one
    for cap in caption:
        cap = '<BOS> '+cap+' <EOS>'
        nWords = cap.count(' ') + 1
        if nWords >= max_caption_length:
            carr = cap.split(' ')
            carr = carr[0:(max_caption_length-2)]
            cap  = ' '.join(carr)
            cap  = cap + ' <EOS>'
            nWords = cap.count(' ')+1
        cap = cap + ' <EOS>'*(max_caption_length-nWords)
        cap_masks.append([1.0]*nWords + [0.0]*(max_caption_length-nWords))
        curr_cap = []
        for word in cap.split(' '):
            #print(word)
            if word in word_to_id.keys():
                curr_cap.append(word_to_id[word]) # word is present in chosen vocabulary
            else:
                curr_cap.append(word_to_id['<UNK>']) # word not present in chosen vocabulary
        caps.append(curr_cap)
        #print('Caption_Length:',len(caps[0]))
    return np.array(caps),np.array(cap_masks)

# %% [markdown]
# ### Train Test  Validation Split

# %%
## Get the list of the files we have extracted features
import os
from sklearn.model_selection import train_test_split

video_list = os.listdir('./DATA/features')
videos = []
for item in video_list:
    videos.append(item.split('-')[0])

video_train, video_test = train_test_split(videos, test_size=0.1, random_state=42)
video_train, video_val = train_test_split(video_train, test_size=0.1, random_state=42)

# %%
print('Training Videos -', len(video_train))
print('Testing Videos -', len(video_test))
print('Validation Videos -', len(video_val))
# Out:
# Training Videos - 5890
# Testing Videos - 728
# Validation Videos - 655

# %% [markdown]
# ### Auxillary functions to handle model build

# %%
import numpy as np
import tensorflow as tf
import glob
import cv2
import imageio
import pickle
np.random.seed(0)
#Global initializations
n_lstm_steps = 30
DATA_DIR = './DATA/'
VIDEO_DIR = DATA_DIR + 'features/'
YOUTUBE_CLIPS_DIR = DATA_DIR + 'videos/'
TEXT_DIR = DATA_DIR+'word_features/'
pkl_file = open('./DATA/word_features/captions.pkl', 'rb')
sentences = pickle.load(pkl_file)
pkl_file.close()
word_counts,unk_required = build_vocab(0)
word2id,id2word = word_to_word_ids(word_counts,unk_required, len(word_counts.keys()))
video_files = video_train
val_files = video_val

print ("{0} files processed".format(len(video_files)))

def get_bias_vector():
    """Function to return the initialization for the bias vector
       for mapping from hidden_dim to vocab_size.
       Borrowed from neuraltalk by Andrej Karpathy"""
    bias_init_vector = np.array([1.0*word_counts[id2word[i]] for i in range(len(id2word))])
    bias_init_vector /= np.sum(bias_init_vector) # normalize to frequencies
    bias_init_vector = np.log(bias_init_vector)
    bias_init_vector -= np.max(bias_init_vector)
    return bias_init_vector

def fetch_data_batch(batch_size):
    """Function to fetch a batch of video features, captions and caption masks
        Input:
                batch_size: Size of batch to load
        Output:
                curr_vids: Features of the randomly selected batch of video_files
                curr_caps: Ground truth (padded) captions for the selected videos
                curr_masks: Mask for the pad locations in curr_caps"""
    curr_batch_vids = np.random.choice(video_files,batch_size)
    curr_vids = np.array([[np.mean(np.load(VIDEO_DIR + vid+'-30-features' + '.npy'), axis=0) for i in range(30)] for vid in curr_batch_vids])
    captions = [np.random.choice(sentences[int(vid[5:])],1)[0]['caption'] for vid in curr_batch_vids]
    curr_caps,curr_masks = convert_caption(captions,word2id,n_lstm_steps)
    return curr_vids,curr_caps,curr_masks

def fetch_data_batch_val(batch_size):
    """Function to fetch a batch of video features from the validation set and its captions.
        Input:
                batch_size: Size of batch to load
        Output:
                curr_vids: Features of the randomly selected batch of video_files
                curr_caps: Ground truth (padded) captions for the selected videos"""

    curr_batch_vids = np.random.choice(val_files,batch_size)
    curr_vids = np.array([[np.mean(np.load(VIDEO_DIR + vid+'-30-features' + '.npy'), axis=0) for i in range(30)] for vid in curr_batch_vids])
    captions = [np.random.choice(sentences[int(vid[5:])],1)[0]['caption'] for vid in curr_batch_vids]
    curr_caps,curr_masks = convert_caption(captions,word2id,n_lstm_steps)
    return curr_vids,curr_caps,curr_masks, curr_batch_vids


def print_in_english(caption_idx):
    """Function to take a list of captions with words mapped to ids and
        print the captions after mapping word indices back to words."""
    captions_english = [[id2word[word] for word in caption] for caption in caption_idx]
    for i,caption in enumerate(captions_english):
        if '<EOS>' in caption:
            caption = caption[0:caption.index('<EOS>')]
        print (str(i+1) + ' ' + ' '.join(caption))
        print ('..................................................')

def playVideo(video_urls):
    video = imageio.get_reader(YOUTUBE_CLIPS_DIR + video_urls[0] + '.mp4','ffmpeg')
    for frame in video:
        fr = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
        cv2.imshow('frame',fr)
        if cv2.waitKey(40) & 0xFF == ord('q'):
            break
    cv2.destroyAllWindows()
# Out:
# 1
# 1 a
# 5890 files processed

# %%
a = np.mean(np.load('./DATA/features/video4804'+'-30-features' + '.npy'), axis=0)
a.shape
# Out:
# (2048,)

# %%
a = (np.load('./DATA/features/video4804'+'-30-features' + '.npy'))
a.shape
# Out:
# (30, 2048)

# %%
print(len(word2id))
# Out:
# 20001

# %%
tmp_val = 'video3707'
np.random.choice(sentences[int(tmp_val[5:])],1)[0]['caption']
# Out:
# 'a woman showing how to make cookies'

# %%
tdata = np.load(VIDEO_DIR+'video0-30-features.npy')
tdata.shape
# Out:
# (30, 2048)

# %%
len(word_counts.keys())
# Out:
# 29325

# %%
print(id2word[0], word2id['a'])
# Out:
# <EOS> 1

# %% [markdown]
# ### Build the model to train

# %%
import numpy as np
import tensorflow as tf
import sys
#GLOBAL VARIABLE INITIALIZATIONS TO BUILD MODEL
n_steps = 30
hidden_dim = 500
frame_dim = 2048
batch_size = 1
vocab_size = len(word2id)
bias_init_vector = get_bias_vector()
n_steps_vocab = 30

def build_model():
    """This function creates weight matrices that transform:
            * frames to caption dimension
            * hidden state to vocabulary dimension
            * creates word embedding matrix """

    print ("Network config: \nN_Steps: {}\nHidden_dim:{}\nFrame_dim:{}\nBatch_size:{}\nVocab_size:{}\n".format(n_steps,
                                                                                                    hidden_dim,
                                                                                                    frame_dim,
                                                                                                    batch_size,
                                                                                                    vocab_size))

    #Create placeholders for holding a batch of videos, captions and caption masks
    video = tf.placeholder(tf.float32,shape=[batch_size,n_steps,frame_dim],name='Input_Video')
    caption = tf.placeholder(tf.int32,shape=[batch_size,n_steps_vocab],name='GT_Caption')
    caption_mask = tf.placeholder(tf.float32,shape=[batch_size,n_steps_vocab],name='Caption_Mask')
    dropout_prob = tf.placeholder(tf.float32,name='Dropout_Keep_Probability')

    with tf.variable_scope('Im2Cap') as scope:
        W_im2cap = tf.get_variable(name='W_im2cap',shape=[frame_dim,
                                                    hidden_dim],
                                                    initializer=tf.random_uniform_initializer(minval=-0.08,maxval=0.08))
        b_im2cap = tf.get_variable(name='b_im2cap',shape=[hidden_dim],
                                                    initializer=tf.constant_initializer(0.0))
    with tf.variable_scope('Hid2Vocab') as scope:
        W_H2vocab = tf.get_variable(name='W_H2vocab',shape=[hidden_dim,vocab_size],
                                                         initializer=tf.random_uniform_initializer(minval=-0.08,maxval=0.08))
        b_H2vocab = tf.Variable(name='b_H2vocab',initial_value=bias_init_vector.astype(np.float32))

    with tf.variable_scope('Word_Vectors') as scope:
        word_emb = tf.get_variable(name='Word_embedding',shape=[vocab_size,hidden_dim],
                                                                initializer=tf.random_uniform_initializer(minval=-0.08,maxval=0.08))
    print ("Created weights")

    #Build two LSTMs, one for processing the video and another for generating the caption
    with tf.variable_scope('LSTM_Video',reuse=None) as scope:
        lstm_vid = tf.nn.rnn_cell.BasicLSTMCell(hidden_dim)
        lstm_vid = tf.nn.rnn_cell.DropoutWrapper(lstm_vid,output_keep_prob=dropout_prob)
    with tf.variable_scope('LSTM_Caption',reuse=None) as scope:
        lstm_cap = tf.nn.rnn_cell.BasicLSTMCell(hidden_dim)
        lstm_cap = tf.nn.rnn_cell.DropoutWrapper(lstm_cap,output_keep_prob=dropout_prob)

    #Prepare input for lstm_video
    video_rshp = tf.reshape(video,[-1,frame_dim])
    video_rshp = tf.nn.dropout(video_rshp,keep_prob=dropout_prob)
    video_emb = tf.nn.xw_plus_b(video_rshp,W_im2cap,b_im2cap)
    video_emb = tf.reshape(video_emb,[batch_size,n_steps,hidden_dim])
    padding = tf.zeros([batch_size,n_steps-1,hidden_dim])
    video_input = tf.concat([video_emb,padding],1)
    #video_input=video_emb
    print ("Video_input: {}".format(video_input.get_shape()))
    #Run lstm_vid for 2*n_steps-1 timesteps
    with tf.variable_scope('LSTM_Video') as scope:
        out_vid,state_vid = tf.nn.dynamic_rnn(lstm_vid,video_input,dtype=tf.float32)
    print ("Video_output: {}".format(out_vid.get_shape()))

    #Prepare input for lstm_cap
    padding = tf.zeros([batch_size,n_steps_vocab,hidden_dim])
    caption_vectors = tf.nn.embedding_lookup(word_emb,caption[:,0:n_steps_vocab-1])
    caption_vectors = tf.nn.dropout(caption_vectors,keep_prob=dropout_prob)
    caption_2n = tf.concat([padding,caption_vectors],1)
    #caption_2n = caption_vectors
    caption_input = tf.concat([caption_2n,out_vid],2)
    print ("Caption_input: {}".format(caption_input.get_shape()))
    #Run lstm_cap for 2*n_steps-1 timesteps
    with tf.variable_scope('LSTM_Caption') as scope:
        out_cap,state_cap = tf.nn.dynamic_rnn(lstm_cap,caption_input,dtype=tf.float32)
    print ("Caption_output: {}".format(out_cap.get_shape()))

    #Compute masked loss
    output_captions = out_cap[:,n_steps_vocab:,:]
    output_logits = tf.reshape(output_captions,[-1,hidden_dim])
    output_logits = tf.nn.dropout(output_logits,keep_prob=dropout_prob)
    output_logits = tf.nn.xw_plus_b(output_logits,W_H2vocab,b_H2vocab)
    output_labels = tf.reshape(caption[:,1:],[-1])
    caption_mask_out = tf.reshape(caption_mask[:,1:],[-1])
    loss = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=output_logits,labels=output_labels)
    masked_loss = loss*caption_mask_out
    loss = tf.reduce_sum(masked_loss)/tf.reduce_sum(caption_mask_out)
    return video,caption,caption_mask,output_logits,loss,dropout_prob

db1 = None
db2 = None
db3 = None
def train():
    global db1,db2,db3
    with tf.Graph().as_default():
        learning_rate = 0.0001
        video,caption,caption_mask,output_logits,loss,dropout_prob = build_model()
        optim = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(loss)
        nEpoch = 300
        nIter = int(nEpoch*6000/batch_size)
        
        ckpt_file = './checkpoint_2d/model_58000.ckpt.meta'

        saver = tf.train.Saver()
        with tf.Session() as sess:
            if ckpt_file:
                saver_ = tf.train.import_meta_graph(ckpt_file)
                saver_.restore(sess,'./checkpoint_2d/model_58000.ckpt')
                print ("Restored model")
            else:
                sess.run(tf.global_variables_initializer())
            for i in range(nIter):
                #print(i)
                vids,caps,caps_mask = fetch_data_batch(batch_size=batch_size)
                db1,db2,db3 = vids, caps, caps_mask
                #print(type(vids),type(caps), type(caps_mask))
                #print(vids,caps, caps_mask)
                _,curr_loss,o_l = sess.run([optim,loss,output_logits],feed_dict={video:vids,
                                                                            caption:caps,
                                                                            caption_mask:caps_mask,
                                                                            dropout_prob:0.5})

                if i%1000 == 0:
                    print ("\nIteration {} \n".format(i))
                    out_logits = o_l.reshape([batch_size,n_steps_vocab-1,vocab_size])
                    output_captions = np.argmax(out_logits,2)
                    #print_in_english(output_captions[0:4])
                    #print ("GT Captions")
                    #print_in_english(caps[0:4])
                    print ("Current train loss: {} ".format(curr_loss))
                    vids,caps,caps_mask,_ = fetch_data_batch_val(batch_size=batch_size)
                    db1,db2,db3 = vids,caps,caps_mask
                    curr_loss,o_l = sess.run([loss,output_logits],feed_dict={video:vids,
                                                                            caption:caps,
                                                                            caption_mask:caps_mask,
                                                                            dropout_prob:1.0})
                    out_logits = o_l.reshape([batch_size,n_steps_vocab-1,vocab_size])
                    output_captions = np.argmax(out_logits,2)
                    print_in_english(output_captions[0:2])
                    print ("GT Captions")
                    print_in_english(caps[0:2])
                    print ("Current validation loss: {} ".format(curr_loss))

                if i%2000 == 0:
                    saver.save(sess,'./checkpoint_2d_mean/model_'+str(i)+'.ckpt')
                    print ('Saved {}'.format(i))

# %% [markdown]
# ### Training Begins !!!

# %%
train()
# Out:
# Network config:
# N_Steps: 30
# Hidden_dim:500
# Frame_dim:2048
# Batch_size:1
# Vocab_size:29325
#
# Created weights
# Video_input: (1, 59, 500)
# Video_output: (1, 59, 500)
# Caption_input: (1, 59, 1000)
# Caption_output: (1, 59, 500)
# INFO:tensorflow:Restoring parameters from ./checkpoint_2d/model_58000.ckpt
# Restored model
#
# Iteration 0
#
# Current train loss: 4.641613006591797
# 1 <BOS> cartoon is <BOS> playing
# ..................................................
# GT Captions
# 1 <BOS> a band of chipmunks covers a jackson five song
# ..................................................
# Current validation loss: 8.981546401977539
# Saved 0
#
# Iteration 1000
#
# Current train loss: 2.427236557006836
# 1 a man is talking an speech
# ..................................................
# GT Captions
# 1 <BOS> a man is giving a ted presentation
# ..................................................
# Current validation loss: 2.665604829788208
#
# Iteration 2000
#
# Current train loss: 4.415088653564453
# 1 a man car car car is on the
# ..................................................
# GT Captions
# 1 <BOS> a  blue color car moving inside forest beside trees slowly displaying on screen
# ..................................................
# Current validation loss: 4.060998439788818
# Saved 2000
#
# Iteration 3000
#
# Current train loss: 4.352205276489258
# 1 a man is about how
# ..................................................
# GT Captions
# 1 <BOS> a woman slicing small squid while explaining how to slice it
# ..................................................
# Current validation loss: 5.182340145111084
#
# Iteration 4000
#
# Current train loss: 3.6574013233184814
# 1 a playing a players
# ..................................................
# GT Captions
# 1 <BOS> pictures of football players posing in the endzone
# ..................................................
# Current validation loss: 5.222723960876465
# Saved 4000
#
# Iteration 5000
#
# Current train loss: 4.498231887817383
# 1 a is reviewing in a pan
# ..................................................
# GT Captions
# 1 <BOS> meat being cooked in a pan
# ..................................................
# Current validation loss: 4.0093464851379395
#
# Iteration 6000
#
# Current train loss: 5.684760570526123
# 1 a and a
# ..................................................
# GT Captions
# 1 <BOS> man wiring somethign electrical
# ..................................................
# Current validation loss: 8.908881187438965
# Saved 6000
#
# Iteration 7000
#
# Current train loss: 4.537549018859863
# 1 a woman is is talking to the
# ..................................................
# GT Captions
# 1 <BOS> a lovely lady is going to explain how to make a a veg and shrimp dish in lemon and garlic sauce
# ..................................................
# Current validation loss: 5.415297031402588
#
# Iteration 8000
#
# Current train loss: 7.19035530090332
# 1 a man is in shown on a
# ..................................................
# GT Captions
# 1 <BOS> a mason layer is working on building something
# ..................................................
# Current validation loss: 5.537885665893555
# Saved 8000
#
# Iteration 9000
#
# Current train loss: 7.128387451171875
# 1 a man clip is about the movie
# ..................................................
# GT Captions
# 1 <BOS> a news reporter talking about a particular crime
# ..................................................
# Current validation loss: 4.202769756317139
#
# Iteration 10000
#
# Current train loss: 5.205630779266357
# 1 a of is
# ..................................................
# GT Captions
# 1 <BOS> portal game short 3d animation
# ..................................................
# Current validation loss: 7.027638912200928
# Saved 10000
#
# Iteration 11000
#
# Current train loss: 6.28781795501709
# 1 a kids are dancing
# ..................................................
# GT Captions
# 1 <BOS> two people are singing on the beach
# ..................................................
# Current validation loss: 1.3611693382263184
#
# Iteration 12000
#
# Current train loss: 4.119054317474365
# 1 a asian for a
# ..................................................
# GT Captions
# 1 <BOS> an advertisement for edible flowers
# ..................................................
# Current validation loss: 5.872984409332275
# Saved 12000
#
# Iteration 13000
#
# Current train loss: 4.530551433563232
# 1 a is a man is making about a dish
# ..................................................
# GT Captions
# 1 <BOS> there is a man is talking about a meet dish
# ..................................................
# Current validation loss: 1.832987666130066
#
# Iteration 14000
#
# Current train loss: 8.274880409240723
# 1 a man of people are a are are in a talking
# ..................................................
# GT Captions
# 1 <BOS> a group of men in business suits standing around and talking to each other
# ..................................................
# Current validation loss: 2.7416329383850098
# Saved 14000
#
# Iteration 15000
#
# Current train loss: 5.588388919830322
# 1 a is showing her make to to her
# ..................................................
# GT Captions
# 1 <BOS> someone is applying the finishing touches of goth styled makeup to their face while looking in a hand held mirror the person is wearing a black wig
# ..................................................
# Current validation loss: 5.617954730987549
#
# Iteration 16000
#
# Current train loss: 2.7057559490203857
# 1 a are playing
# ..................................................
# GT Captions
# 1 <BOS> people are controlling puppets who are talking to each other
# ..................................................
# Current validation loss: 4.3849287033081055
# Saved 16000
#
# Iteration 17000
#
# Current train loss: 2.578556776046753
# 1 a are in a video
# ..................................................
# GT Captions
# 1 <BOS> men fighting in a war
# ..................................................
# Current validation loss: 2.8141555786132812
#
# Iteration 18000
#
# Current train loss: 3.8266916275024414
# 1 a man is a car
# ..................................................
# GT Captions
# 1 <BOS> a man showcasing a vehicle part
# ..................................................
# Current validation loss: 3.7110631465911865
# Saved 18000
#
# Iteration 19000
#
# Current train loss: 3.7711563110351562
# 1 a man man is a a water
# ..................................................
# GT Captions
# 1 <BOS> a little girl surf in the water of the beach while the waves raising
# ..................................................
# Current validation loss: 3.9100873470306396
#
# Iteration 20000
#
# Current train loss: 4.194765090942383
# 1 a person is a cooking show
# ..................................................
# GT Captions
# 1 <BOS> a person doing a cooking show and showing the ingredients for the recipe
# ..................................................
# Current validation loss: 1.3191936016082764
# Saved 20000
#
# Iteration 21000
#
# Current train loss: 5.572749614715576
# 1 a person is a and in being
# ..................................................
# GT Captions
# 1 <BOS> a box of the cage is shown and how to make a cage is explained
# ..................................................
# Current validation loss: 3.817539930343628
#
# Iteration 22000
#
# Current train loss: 3.9758312702178955
# 1 a men talking a woman talking
# ..................................................
# GT Captions
# 1 <BOS> two woman and a man give a talk on a tv show
# ..................................................
# Current validation loss: 3.094536066055298
# Saved 22000
#
# Iteration 23000
#
# Current train loss: 3.778292417526245
# 1 a man up is are about
# ..................................................
# GT Captions
# 1 <BOS> the make up men telling their make up secret to their fans in very  simply
# ..................................................
# Current validation loss: 5.386987686157227
#
# Iteration 24000
#
# Current train loss: 4.160089492797852
# 1 a person person of to a people and a
# ..................................................
# GT Captions
# 1 <BOS> a white bowl next to two cups of sauce with with white powder being poured into the white bowl
# ..................................................
# Current validation loss: 4.481175422668457
# Saved 24000
#
# Iteration 25000
#
# Current train loss: 4.757170677185059
# 1 a man man man man in
# ..................................................
# GT Captions
# 1 <BOS> a little blonde 8-year-old costa rican girl surfs on a small wave
# ..................................................
# Current validation loss: 7.883027076721191
# Iteration 26000
#
# Current train loss: 0.6208784580230713
# 1 a woman is a dress is is about the room
# ..................................................
# GT Captions
# 1 <BOS> a woman in red patterned dress talks in a room inside of a home
# ..................................................
# Current validation loss: 3.434427499771118
# Saved 26000
#
# Iteration 27000
#
# Current train loss: 5.202625751495361
# 1 a is is showing a tutorial tutorial
# ..................................................
# GT Captions
# 1 <BOS> this woman is giving a computer tutorial
# ..................................................
# Current validation loss: 2.621931552886963
#
# Iteration 28000
#
# Current train loss: 1.1305757761001587
# 1 a man is driving a talking about a camera
# ..................................................
# GT Captions
# 1 <BOS> a man is driving and talking to the camera between shots of the road and time lapse video of men arranging things items in the back of
# ..................................................
# Current validation loss: 4.353454113006592
# Saved 28000
#
# Iteration 29000
#
# Current train loss: 0.9616796970367432
# 1 a men are to a
# ..................................................
# GT Captions
# 1 <BOS> two females talking about candy
# ..................................................
# Current validation loss: 5.038581371307373
#
# Iteration 30000
#
# Current train loss: 6.8563151359558105
# 1 a man is a man are in
# ..................................................
# GT Captions
# 1 <BOS> a chicken and a cat fighting
# ..................................................
# Current validation loss: 4.030206203460693
# Saved 30000
#
# Iteration 31000
#
# Current train loss: 4.2478156089782715
# 1 a man of the of the man
# ..................................................
# GT Captions
# 1 <BOS> a cartoon describing one of the first video games created
# ..................................................
# Current validation loss: 4.461965560913086
#
# Iteration 32000
#
# Current train loss: 5.713459014892578
# 1 a car is talking about a car of a car
# ..................................................
# GT Captions
# 1 <BOS> a woman is talking about the exterior of her car
# ..................................................
# Current validation loss: 2.3588953018188477
# Saved 32000
#
# Iteration 33000
#
# Current train loss: 2.519374370574951
# 1 a are talking on a stage
# ..................................................
# GT Captions
# 1 <BOS> people are working on a project in an office setting
# ..................................................
# Current validation loss: 3.9119489192962646
#
# Iteration 34000
#
# Current train loss: 4.5762152671813965
# 1 a man is playing
# ..................................................
# GT Captions
# 1 <BOS> a man is walking
# ..................................................
# Current validation loss: 2.1976523399353027
# Saved 34000
#
# Iteration 35000
#
# Current train loss: 3.030790328979492
# 1 a man is a are talking
# ..................................................
# GT Captions
# 1 <BOS> a man and woman are speaking at a table
# ..................................................
# Current validation loss: 1.8848918676376343
#
# Iteration 36000
#
# Current train loss: 4.072572708129883
# 1 a man is in food
# ..................................................
# GT Captions
# 1 <BOS> a man operates a phone while flower displays and such are passed by
# ..................................................
# Current validation loss: 6.2800493240356445
# Saved 36000
#
# Iteration 37000
#
# Current train loss: 6.020367622375488
# 1 a man is is talking a
# ..................................................
# GT Captions
# 1 <BOS> a cartoon man is holding money
# ..................................................
# Current validation loss: 3.073838472366333
#
# Iteration 38000
#
# Current train loss: 3.043222665786743
# 1 a man of are playing
# ..................................................
# GT Captions
# 1 <BOS> a couple people are commentating over the video game minecraft
# ..................................................
# Current validation loss: 3.269869804382324
# Saved 38000
#
# Iteration 39000
#
# Current train loss: 7.800485134124756
# 1 a man is cooking
# ..................................................
# GT Captions
# 1 <BOS> a man is cooking some dish in the kadai
# ..................................................
# Current validation loss: 3.0894575119018555
#
# Iteration 40000
#
# Current train loss: 3.580012559890747
# 1 a woman is about a about the movie
# ..................................................
# GT Captions
# 1 <BOS> a woman news anchor talks about a debate on fox news
# ..................................................
# Current validation loss: 4.192366123199463
# Saved 40000
#
# Iteration 41000
#
# Current train loss: 3.54923677444458
# 1 a woman is a blue and of about the camera
# ..................................................
# GT Captions
# 1 <BOS> the woman in the tank top talk with the large trees behind her
# ..................................................
# Current validation loss: 4.029400825500488
#
# Iteration 42000
#
# Current train loss: 1.844306230545044
# 1 a old woman is about the
# ..................................................
# GT Captions
# 1 <BOS> an old lady speaking about children
# ..................................................
# Current validation loss: 2.9518485069274902
# Saved 42000
#
# Iteration 43000
#
# Current train loss: 5.414315700531006
# 1 a man man is a is
# ..................................................
# GT Captions
# 1 <BOS> a long pause of blank space beofore the inevidible conclusion
# ..................................................
# Current validation loss: 9.690408706665039
#
# Iteration 44000
#
# Current train loss: 3.0034070014953613
# 1 a man is
# ..................................................
# GT Captions
# 1 <BOS> a car commercial about the inside and outside
# ..................................................
# Current validation loss: 3.3139169216156006
# Saved 44000
#
# Iteration 45000
#
# Current train loss: 7.031601905822754
# 1 a man of a
# ..................................................
# GT Captions
# 1 <BOS> a set of reporters provide political commentary
# ..................................................
# Current validation loss: 6.465195655822754
#
# Iteration 46000
#
# Current train loss: 3.4231204986572266
# 1 a players is a football
# ..................................................
# GT Captions
# 1 <BOS> football player makes an amazing tackle
# ..................................................
# Current validation loss: 5.299428462982178
# Saved 46000
#
# Iteration 47000
#
# Current train loss: 4.78629732131958
# 1 a woman is a fashion dress is down a runway
# ..................................................
# GT Captions
# 1 <BOS> a model in a pink dress struts down the runway followed by another in black and white
# ..................................................
# Current validation loss: 3.9193544387817383
#
# Iteration 48000
#
# Current train loss: 4.7467451095581055
# 1 a woman is to a video
# ..................................................
# GT Captions
# 1 <BOS> a woman speaks in a classroom
# ..................................................
# Current validation loss: 2.4385628700256348
# Saved 48000
#
# Iteration 49000
#
# Current train loss: 3.7783524990081787
# 1 a of being
# ..................................................
# GT Captions
# 1 <BOS> alligators are pursuing a man
# ..................................................
# Current validation loss: 7.268395900726318
#
# Iteration 50000
#
# Current train loss: 3.792604684829712
# 1 a man is a
# ..................................................
# GT Captions
# 1 <BOS> a person playing gta 5
# ..................................................
# Current validation loss: 4.730972766876221
# Saved 50000
#
# Iteration 51000
#
# Current train loss: 6.909889221191406
# 1 a man is showing a cooking
# ..................................................
# GT Captions
# 1 <BOS> a man is doing a tutorial on plumbing
# ..................................................
# Current validation loss: 3.1088976860046387
#
# Iteration 52000
#
# Current train loss: 5.409278869628906
# 1 a man is in food
# ..................................................
# GT Captions
# 1 <BOS> a lion attacking some deers
# ..................................................
# Current validation loss: 6.806463718414307
# Saved 52000
#
# Iteration 53000
#
# Current train loss: 4.2463202476501465
# 1 a is cooking food
# ..................................................
# GT Captions
# 1 <BOS> someone is cooking dumplings
# ..................................................
# Current validation loss: 3.6545937061309814
#
# Iteration 54000
#
# Current train loss: 6.301228046417236
# 1 a person is a bowl
# ..................................................
# GT Captions
# 1 <BOS> a person peeling a potato then mashing it in a bowl
# ..................................................
# Current validation loss: 4.211101531982422
# Saved 54000
#
# Iteration 55000
#
# Current train loss: 4.629186630249023
# 1 a of talking are
# ..................................................
# GT Captions
# 1 <BOS> 2015 long jump qualifiers listed on a slideshow from the website keinanbriggs
# ..................................................
# Current validation loss: 8.288712501525879
#
# Iteration 56000
#
# Current train loss: 3.4808053970336914
# 1 a man is a black shirt shirt is talking to to a
# ..................................................
# GT Captions
# 1 <BOS> a woman wearing a green floral shirt is applying makeup for online viewers
# ..................................................
# Current validation loss: 4.5487141609191895
# Saved 56000
#
# Iteration 57000
#
# Current train loss: 2.3006937503814697
# 1 a playing a
# ..................................................
# GT Captions
# 1 <BOS> kids throws football at target
# ..................................................
# Current validation loss: 5.942592144012451
#
# Iteration 58000
#
# Current train loss: 6.611450672149658
# 1 a is a man of a man
# ..................................................
# GT Captions
# 1 <BOS> it is a video about a guy saying how he wants a normal life and to change
# ..................................................
# Current validation loss: 4.65264892578125
# Saved 58000
#
# Iteration 59000
#
# Current train loss: 5.134349346160889
# 1 a of of the beach
# ..................................................
# GT Captions
# 1 <BOS> game play from the paw patrol show
# ..................................................
# Current validation loss: 6.152743816375732
#
# Iteration 60000
#
# Current train loss: 7.429018020629883
# 1 a cartoon is at a cartoon
# ..................................................
# GT Captions
# 1 <BOS> a family looking at some rose pedals on the floor
# ..................................................
# Current validation loss: 5.001985549926758
# Saved 60000
#
# Iteration 61000
#
# Current train loss: 1.6090723276138306
# 1 a woman is a face
# ..................................................
# GT Captions
# 1 <BOS> a woman discusses her disappointment in the interior packaging of the gwen stefani makeup kit
# ..................................................
# Current validation loss: 6.959815979003906
#
# Iteration 62000
#
# Current train loss: 3.76898455619812
# 1 a man man is
# ..................................................
# GT Captions
# 1 <BOS> a cartoon involving animals
# ..................................................
# Current validation loss: 4.56723690032959
# Saved 62000
#
# Iteration 63000
#
# Current train loss: 2.652405023574829
# 1 a man of people people are a are talking to
# ..................................................
# GT Captions
# 1 <BOS> a group of  men and woman are trying to push there way through a crowd
# ..................................................
# Current validation loss: 3.915295362472534
#
# Iteration 64000
#
# Current train loss: 2.488001585006714
# 1 a man is about a video game
# ..................................................
# GT Captions
# 1 <BOS> a narrator talks over a video game scene
# ..................................................
# Current validation loss: 2.792877435684204
# Saved 64000
#
# Iteration 65000
#
# Current train loss: 4.235859394073486
# 1 a man man is in the man is about the
# ..................................................
# GT Captions
# 1 <BOS> a small dog something and a lady talking about it
# ..................................................
# Current validation loss: 3.3053696155548096
#
# Iteration 66000
#
# Current train loss: 5.798431873321533
# 1 a group of people are on a room
# ..................................................
# GT Captions
# 1 <BOS> a group of children sitting in a classroom
# ..................................................
# Current validation loss: 2.0664801597595215
# Saved 66000
#
# Iteration 67000
#
# Current train loss: 1.1184570789337158
# 1 a animated is white is is shown shown
# ..................................................
# GT Captions
# 1 <BOS> an orange and black bike is being shown to people
# ..................................................
# Current validation loss: 3.3547468185424805
#
# Iteration 68000
#
# Current train loss: 3.3083109855651855
# 1 a cartoon is a in talking a man
# ..................................................
# GT Captions
# 1 <BOS> a robot presses buttons and starts a count down
# ..................................................
# Current validation loss: 6.891602516174316
# Saved 68000
#
# Iteration 69000
#
# Current train loss: 4.2728047370910645
# 1 a man is playing a video game
# ..................................................
# GT Captions
# 1 <BOS> a person is playing a video game
# ..................................................
# Current validation loss: 0.45575863122940063
#
# Iteration 70000
#
# Current train loss: 4.105396270751953
# 1 a woman is a black shirt is a a hair hair is talking a talking
# ..................................................
# GT Captions
# 1 <BOS> a woman wearing a red shirt and with short blonde hair is holding and rotating a gray spotted pet bed
# ..................................................
# Current validation loss: 4.681107521057129
# Saved 70000
#
# Iteration 71000
#
# Current train loss: 4.743237495422363
# 1 a man for a movie
# ..................................................
# GT Captions
# 1 <BOS> a trailer for a movie
# ..................................................
# Current validation loss: 1.6128416061401367
#
# Iteration 72000
#
# Current train loss: 1.2847034931182861
# 1 a woman is making a piece of paper
# ..................................................
# GT Captions
# 1 <BOS> a man is folding a piece of paper
# ..................................................
# Current validation loss: 1.1859912872314453
# Saved 72000
#
# Iteration 73000
#
# Current train loss: 5.732892990112305
# 1 a are are in a man
# ..................................................
# GT Captions
# 1 <BOS> four people shown carrying a dead body and after ten year there was a huge building in that place
# ..................................................
# Current validation loss: 6.193070888519287
#
# Iteration 74000
#
# Current train loss: 4.597732067108154
# 1 a man is how her
# ..................................................
# GT Captions
# 1 <BOS> a girl showing off her room and letting viewers know where she purchased her nine-drawer unit from
# ..................................................
# Current validation loss: 7.008563041687012
# Saved 74000
#
# Iteration 75000
#
# Current train loss: 4.233100414276123
# 1 a man is in
# ..................................................
# GT Captions
# 1 <BOS> the scale was very accurate
# ..................................................
# Current validation loss: 7.1058783531188965
#
# Iteration 76000
#
# Current train loss: 6.322752952575684
# 1 a man is a video game
# ..................................................
# GT Captions
# 1 <BOS> a man discusses a video game that is a shark simulator
# ..................................................
# Current validation loss: 3.818161725997925
# Saved 76000
#
# Iteration 77000
#
# Current train loss: 2.577007293701172
# 1 a men are about a tv
# ..................................................
# GT Captions
# 1 <BOS> nosey people talking in a room
# ..................................................
# Current validation loss: 4.723308086395264
#
# Iteration 78000
#
# Current train loss: 4.185486793518066
# 1 a video from a video game game
# ..................................................
# GT Captions
# 1 <BOS> a scene from a violent video game is playing
# ..................................................
# Current validation loss: 2.480949878692627
# Saved 78000
#
# Iteration 79000
#
# Current train loss: 1.6745507717132568
# 1 a a in in video game
# ..................................................
# GT Captions
# 1 <BOS> having fun playing a video game
# ..................................................
# Current validation loss: 3.3993821144104004
# Iteration 80000
#
# Current train loss: 6.179161071777344
# 1 a man is on a race
# ..................................................
# GT Captions
# 1 <BOS> a man talked about a starbucks and what you can out of the window
# ..................................................
# Current validation loss: 4.860806941986084
# Saved 80000
#
# Iteration 81000
#
# Current train loss: 6.7100982666015625
# 1 a person is is the and and
# ..................................................
# GT Captions
# 1 <BOS> the truck drove up
# ..................................................
# Current validation loss: 6.135601043701172
#
# Iteration 82000
#
# Current train loss: 1.9340616464614868
# 1 a of a video video
# ..................................................
# GT Captions
# 1 <BOS> demonstration of a new vehicle on the market
# ..................................................
# Current validation loss: 4.475976943969727
# Saved 82000
#
# Iteration 83000
#
# Current train loss: 9.98462200164795
# 1 a is car on the the
# ..................................................
# GT Captions
# 1 <BOS> volkswagen toureg going through off road
# ..................................................
# Current validation loss: 7.324889183044434
#
# Iteration 84000
#
# Current train loss: 4.678687572479248
# 1 a man is a on
# ..................................................
# GT Captions
# 1 <BOS>  arnie clarke director exports sales briefing his business
# ..................................................
# Current validation loss: 10.930596351623535
# Saved 84000
#
# Iteration 85000
#
# Current train loss: 4.688064098358154
# 1 a woman woman how to make a makeup
# ..................................................
# GT Captions
# 1 <BOS> a teen shows how to do the cat eye
# ..................................................
# Current validation loss: 3.996950626373291
#
# Iteration 86000
#
# Current train loss: 7.042771816253662
# 1 a is a cartoon of is
# ..................................................
# GT Captions
# 1 <BOS> glimpses of a animation game
# ..................................................
# Current validation loss: 5.040493965148926
# Saved 86000
#
# Iteration 87000
#
# Current train loss: 2.429579734802246
# 1 a men are a
# ..................................................
# GT Captions
# 1 <BOS> two persons having masks of angry birds on their heads
# ..................................................
# Current validation loss: 5.982439994812012
#
# Iteration 88000
#
# Current train loss: 3.0474772453308105
# 1 a of talking in a water
# ..................................................
# GT Captions
# 1 <BOS> peter is driving in the car
# ..................................................
# Current validation loss: 3.9310290813446045
# Saved 88000
#
# Iteration 89000
#
# Current train loss: 6.9466071128845215
# 1 a man is showing how to make a
# ..................................................
# GT Captions
# 1 <BOS> a man is showing how to perform home repair jobs
# ..................................................
# Current validation loss: 3.9578497409820557
#
# Iteration 90000
#
# Current train loss: 4.01255464553833
# 1 a man is a of of a table
# ..................................................
# GT Captions
# 1 <BOS> a man thanking the viewer at the end of his video
# ..................................................
# Current validation loss: 4.438778400421143
# Saved 90000
#
# Iteration 91000
#
# Current train loss: 4.783598899841309
# 1 a man is cooking a ingredients in a pan
# ..................................................
# GT Captions
# 1 <BOS> a man is pouring a coke in a pan and talking about that
# ..................................................
# Current validation loss: 2.6919867992401123
#
# Iteration 92000
#
# Current train loss: 3.0595927238464355
# 1 a woman is on up
# ..................................................
# GT Captions
# 1 <BOS> a girl puts make up in the cheek and shows some box of colours
# ..................................................
# Current validation loss: 4.36680269241333
# Saved 92000
#
# Iteration 93000
#
# Current train loss: 4.743095397949219
# 1 a man man is with with
# ..................................................
# GT Captions
# 1 <BOS> a young boy plays an instrument while a man watches
# ..................................................
# Current validation loss: 3.7112016677856445
#
# Iteration 94000
#
# Current train loss: 3.4066059589385986
# 1 a man news interviewed about a tv
# ..................................................
# GT Captions
# 1 <BOS> a male being interviewed in a lecture hall
# ..................................................
# Current validation loss: 3.670959949493408
# Saved 94000
#
# Iteration 95000
#
# Current train loss: 6.8523712158203125
# 1 a from a wrestling game
# ..................................................
# GT Captions
# 1 <BOS> scene from a basketball game
# ..................................................
# Current validation loss: 1.7744911909103394
#
# Iteration 96000
#
# Current train loss: 3.1349120140075684
# 1 a are playing in a table
# ..................................................
# GT Captions
# 1 <BOS> children are sitting on a rug in a classroom
# ..................................................
# Current validation loss: 3.4690215587615967
# Saved 96000
#
# Iteration 97000
#
# Current train loss: 6.5214762687683105
# 1 a girl is a is talking a room
# ..................................................
# GT Captions
# 1 <BOS> a man with puppets is in a jump castle
# ..................................................
# Current validation loss: 4.7489728927612305
#
# Iteration 98000
#
# Current train loss: 2.6398513317108154
# 1 a woman is a are a news
# ..................................................
# GT Captions
# 1 <BOS> a boy and girl watching the frozen son let it go on a monitor in different languages
# ..................................................
# Current validation loss: 5.381913661956787
# Saved 98000
#
# Iteration 99000
#
# Current train loss: 3.6068830490112305
# 1 a man is talking about
# ..................................................
# GT Captions
# 1 <BOS> a girl is talking something
# ..................................................
# Current validation loss: 2.248502016067505
#
# Iteration 100000
#
# Current train loss: 5.464990139007568
# 1 a woman is about the
# ..................................................
# GT Captions
# 1 <BOS> a woman talks about helping children while scenes from a classroom are shown
# ..................................................
# Current validation loss: 3.4174230098724365
# Saved 100000
#
# Iteration 101000
#
# Current train loss: 2.309807062149048
# 1 a man is a car
# ..................................................
# GT Captions
# 1 <BOS> a person driving a car and commenting
# ..................................................
# Current validation loss: 2.861771583557129
#
# Iteration 102000
#
# Current train loss: 4.364327907562256
# 1 a playing playing in a horse
# ..................................................
# GT Captions
# 1 <BOS> girl are walking with a horse
# ..................................................
# Current validation loss: 2.3935964107513428
# Saved 102000
#
# Iteration 103000
#
# Current train loss: 1.6234017610549927
# 1 a woman is is
# ..................................................
# GT Captions
# 1 <BOS> a napoleon dynamite wannabe is rapping about donatello and nun-chucks while wearing a wig and a construction paper mask
# ..................................................
# Current validation loss: 8.740696907043457
#
# Iteration 104000
#
# Current train loss: 4.239906311035156
# 1 cartoon a cartoon cartoon show
# ..................................................
# GT Captions
# 1 <BOS> in a cartoon television show a yellow skelton character is displayed
# ..................................................
# Current validation loss: 4.375360012054443
# Saved 104000
#
# Iteration 105000
#
# Current train loss: 5.301202297210693
# 1 a man is a man
# ..................................................
# GT Captions
# 1 <BOS> a woman teaches a chinese dialect with a chalkboard and pointer
# ..................................................
# Current validation loss: 6.897315979003906
#
# Iteration 106000
#
# Current train loss: 0.863053023815155
# 1 a of a are playing a
# ..................................................
# GT Captions
# 1 <BOS> images of people are on spheres that spin around
# ..................................................
# Current validation loss: 6.431740760803223
# Saved 106000
#
# Iteration 107000
#
# Current train loss: 6.469492435455322
# 1 a person is showing a toy
# ..................................................
# GT Captions
# 1 <BOS> a man is holding a coffee mug
# ..................................................
# Current validation loss: 3.9400477409362793
#
# Iteration 108000
#
# Current train loss: 3.9650444984436035
# 1 a man are the
# ..................................................
# GT Captions
# 1 <BOS> the awesome jets scored a touchdown under pressure
# ..................................................
# Current validation loss: 8.76272201538086
# Saved 108000
#
# Iteration 109000
#
# Current train loss: 4.827478885650635
# 1 a man is driving a
# ..................................................
# GT Captions
# 1 <BOS> a man is filming himself in a car
# ..................................................
# Current validation loss: 2.3142709732055664
#
# Iteration 110000
#
# Current train loss: 5.506858825683594
# 1 a woman is talking a computer
# ..................................................
# GT Captions
# 1 <BOS> a woman is using a microscope and a pc
# ..................................................
# Current validation loss: 3.7199885845184326
# Saved 110000
#
# Iteration 111000
#
# Current train loss: 4.359864234924316
# 1 a man is talking about a audience
# ..................................................
# GT Captions
# 1 <BOS> a man is talking to an audience
# ..................................................
# Current validation loss: 1.2582740783691406
#
# Iteration 112000
#
# Current train loss: 3.9877891540527344
# 1 a men are talking are a man talking to
# ..................................................
# GT Captions
# 1 <BOS> two children are there and one is talking
# ..................................................
# Current validation loss: 3.3981270790100098
# Saved 112000
#
# Iteration 113000
#
# Current train loss: 5.1690287590026855
# 1 a woman is in a track and the woman car is
# ..................................................
# GT Captions
# 1 <BOS> a woman running down a path and a white ambulance parked on the side of the road
# ..................................................
# Current validation loss: 3.503086566925049
#
# Iteration 114000
#
# Current train loss: 2.6506502628326416
# 1 a is a playing on a football game
# ..................................................
# GT Captions
# 1 <BOS> there is male commentary over a football game
# ..................................................
# Current validation loss: 3.234706401824951
# Saved 114000
#
# Iteration 115000
#
# Current train loss: 1.040629506111145
# 1 a is a a man of in a
# ..................................................
# GT Captions
# 1 <BOS> there is  a video coverage of cooking by a person
# ..................................................
# Current validation loss: 4.316014766693115
#
# Iteration 116000
#
# Current train loss: 4.602266788482666
# 1 a man is how of a car
# ..................................................
# GT Captions
# 1 <BOS> a man showing parts on his motorcycle
# ..................................................
# Current validation loss: 3.1077656745910645
# Saved 116000
#
# Iteration 117000
#
# Current train loss: 6.582874774932861
# 1 a man is talking a woman
# ..................................................
# GT Captions
# 1 <BOS> a guy is taking a photo with his phone
# ..................................................
# Current validation loss: 3.169827938079834
#
# Iteration 118000
#
# Current train loss: 2.293328285217285
# 1 a man is a blue shirt is in a of a computer shirt
# ..................................................
# GT Captions
# 1 <BOS> a man in a black tshirt stands in front of a blue wall and talks
# ..................................................
# Current validation loss: 2.1960878372192383
# Saved 118000
#
# Iteration 119000
#
# Current train loss: 4.840322971343994
# 1 a woman is talking a
# ..................................................
# GT Captions
# 1 <BOS> a woman is discussing actresses
# ..................................................
# Current validation loss: 3.509927988052368
#
# Iteration 120000
#
# Current train loss: 2.639061450958252
# 1 a man is are playing a
# ..................................................
# GT Captions
# 1 <BOS> a couple people are playing minecraft
# ..................................................
# Current validation loss: 2.436697483062744
# Saved 120000
#
# Iteration 121000
#
# Current train loss: 3.245490074157715
# 1 a are are man
# ..................................................
# GT Captions
# 1 <BOS> lassie saving a dog and elvis singing
# ..................................................
# Current validation loss: 8.209444046020508
#
# Iteration 122000
#
# Current train loss: 0.9867674112319946
# 1 a man game is from shown on
# ..................................................
# GT Captions
# 1 <BOS> a video game scene is going of rugby
# ..................................................
# Current validation loss: 3.0409138202667236
# Saved 122000
#
# Iteration 123000
#
# Current train loss: 4.517143249511719
# 1 a people are in a video
# ..................................................
# GT Captions
# 1 <BOS> some people argue during a war
# ..................................................
# Current validation loss: 4.887123107910156
#
# Iteration 124000
#
# Current train loss: 3.8627567291259766
# 1 a person is showing a
# ..................................................
# GT Captions
# 1 <BOS> a man is discussing computer
# ..................................................
# Current validation loss: 2.7736847400665283
# Saved 124000
#
# Iteration 125000
#
# Current train loss: 9.016942977905273
# 1 a car of a car of a car
# ..................................................
# GT Captions
# 1 <BOS> the interior and the facilities of the volks wagen car is very useful and wonderful
# ..................................................
# Current validation loss: 7.198856353759766
#
# Iteration 126000
#
# Current train loss: 7.2248663902282715
# 1 a man is a suit is a man a suit shirt is about a of
# ..................................................
# GT Captions
# 1 <BOS> a man in a suit and another in a plaid shirt talk about variety madgazine
# ..................................................
# Current validation loss: 4.210700035095215
# Saved 126000
#
# Iteration 127000
#
# Current train loss: 3.3496406078338623
# 1 a animated video is being
# ..................................................
# GT Captions
# 1 <BOS> an animated car is driving on the road
# ..................................................
# Current validation loss: 2.21209454536438
#
# Iteration 128000
#
# Current train loss: 6.325496673583984
# 1 a man is a old
# ..................................................
# GT Captions
# 1 <BOS> a man describes an environment
# ..................................................
# Current validation loss: 3.8869616985321045
# Saved 128000
#
# Iteration 129000
#
# Current train loss: 8.619894027709961
# 1 a is a video
# ..................................................
# GT Captions
# 1 <BOS> someone playing a driving game
# ..................................................
# Current validation loss: 3.418726921081543
#
# Iteration 130000
#
# Current train loss: 4.073558330535889
# 1 a person is a ingredients
# ..................................................
# GT Captions
# 1 <BOS> a person describing the paper folding craft
# ..................................................
# Current validation loss: 3.7360761165618896
# Saved 130000
#
# Iteration 131000
#
# Current train loss: 2.197190284729004
# 1 a is a man is in the water in
# ..................................................
# GT Captions
# 1 <BOS> there is a woman surfing on the powerful waves
# ..................................................
# Current validation loss: 4.0303955078125
#
# Iteration 132000
#
# Current train loss: 5.344985485076904
# 1 a man are talking
# ..................................................
# GT Captions
# 1 <BOS> young men are yelling at each other
# ..................................................
# Current validation loss: 3.491032600402832
# Saved 132000
#
# Iteration 133000
#
# Current train loss: 5.101109504699707
# 1 a kids are playing a other
# ..................................................
# GT Captions
# 1 <BOS> two boys are hitting each other in the back with a bat
# ..................................................
# Current validation loss: 3.5554792881011963
# Iteration 134000
#
# Current train loss: 7.426659107208252
# 1 a man is driving about a car of
# ..................................................
# GT Captions
# 1 <BOS> a man is talking about the seat room in a car
# ..................................................
# Current validation loss: 2.2225892543792725
# Saved 134000
#
# Iteration 135000
#
# Current train loss: 5.389339923858643
# 1 a is playing a game
# ..................................................
# GT Captions
# 1 <BOS> someone is playing a game
# ..................................................
# Current validation loss: 0.5735676288604736
#
# Iteration 136000
#
# Current train loss: 4.075915813446045
# 1 a girl is talking a video of a
# ..................................................
# GT Captions
# 1 <BOS> a woman is taking a video of herself
# ..................................................
# Current validation loss: 2.798659086227417
# Saved 136000
#
# Iteration 137000
#
# Current train loss: 3.9081692695617676
# 1 a man is the to make a
# ..................................................
# GT Captions
# 1 <BOS> a women describes how to use gearties for your cables
# ..................................................
# Current validation loss: 6.130490303039551
#
# Iteration 138000
#
# Current train loss: 3.6377601623535156
# 1 a woman is cooking a in
# ..................................................
# GT Captions
# 1 <BOS> a man is tossing cooked potatoes in a bowl to transfer the flavor
# ..................................................
# Current validation loss: 5.463639736175537
# Saved 138000
#
# Iteration 139000
#
# Current train loss: 8.157743453979492
# 1 a animated man of people are
# ..................................................
# GT Captions
# 1 <BOS> an animated group of whales swim around the ocean while other wildlife is also showcased
# ..................................................
# Current validation loss: 6.042141914367676
#
# Iteration 140000
#
# Current train loss: 3.247349262237549
# 1 a man
# ..................................................
# GT Captions
# 1 <BOS> the news about the meeting
# ..................................................
# Current validation loss: 3.928126096725464
# Saved 140000
#
# Iteration 141000
#
# Current train loss: 4.716679573059082
# 1 a woman is a man
# ..................................................
# GT Captions
# 1 <BOS> a man gutting a fish
# ..................................................
# Current validation loss: 5.1316351890563965
#
# Iteration 142000
#
# Current train loss: 5.832327842712402
# 1 a wrestling are in
# ..................................................
# GT Captions
# 1 <BOS> multiple women lift weights in a weight lifting competition
# ..................................................
# Current validation loss: 6.835843563079834
# Saved 142000
#
# Iteration 143000
#
# Current train loss: 5.533493995666504
# 1 a people are to a a a road
# ..................................................
# GT Captions
# 1 <BOS> many cars try to drive down a road on rainy day until a bus blocks the road
# ..................................................
# Current validation loss: 5.656900882720947
#
# Iteration 144000
#
# Current train loss: 4.8056640625
# 1 a boy of kids kids are at a table
# ..................................................
# GT Captions
# 1 <BOS> a group of young people sit at a table and eat food
# ..................................................
# Current validation loss: 2.6225192546844482
# Saved 144000
#
# Iteration 145000
#
# Current train loss: 9.01173210144043
# 1 a woman is a
# ..................................................
# GT Captions
# 1 <BOS> a woman feeds baby food from a jar to her baby
# ..................................................
# Current validation loss: 4.4266533851623535
#
# Iteration 146000
#
# Current train loss: 4.358706951141357
# 1 a driving driving a car
# ..................................................
# GT Captions
# 1 <BOS> michael meyers in the movie wayne s world is talking with another man
# ..................................................
# Current validation loss: 6.420165538787842
# Saved 146000
#
# Iteration 147000
#
# Current train loss: 4.815150260925293
# 1 a men players are a playing the ball
# ..................................................
# GT Captions
# 1 <BOS> two soccer teams pass and kick the ball down a grassy field
# ..................................................
# Current validation loss: 4.696181297302246
#
# Iteration 148000
#
# Current train loss: 6.004348278045654
# 1 a man trailer is shown
# ..................................................
# GT Captions
# 1 <BOS> a movie trailer is shown with army characters
# ..................................................
# Current validation loss: 3.039217472076416
# Saved 148000
#
# Iteration 149000
#
# Current train loss: 1.787989854812622
# 1 a man is a motorcycle
# ..................................................
# GT Captions
# 1 <BOS> a man riding a bike down a steep trail through a bunch of trees in a forest
# ..................................................
# Current validation loss: 3.2785484790802
#
# Iteration 150000
#
# Current train loss: 2.6562366485595703
# 1 a talking talking
# ..................................................
# GT Captions
# 1 <BOS> man is meeting his old friend who is in prison
# ..................................................
# Current validation loss: 5.158056735992432
# Saved 150000
#
# Iteration 151000
#
# Current train loss: 3.1187140941619873
# 1 a man is a black is and man in a black
# ..................................................
# GT Captions
# 1 <BOS> a man in a suit hands another man in a suit some gum
# ..................................................
# Current validation loss: 3.6723363399505615
#
# Iteration 152000
#
# Current train loss: 2.290621042251587
# 1 a woman is talking a news
# ..................................................
# GT Captions
# 1 <BOS> a person is presenting the news
# ..................................................
# Current validation loss: 2.191450595855713
# Saved 152000
#
# Iteration 153000
#
# Current train loss: 3.4797558784484863
# 1 a men are a tennis in a man is the shirt
# ..................................................
# GT Captions
# 1 <BOS> two men play table tennis and the one in blue wins
# ..................................................
# Current validation loss: 2.96869158744812
#
# Iteration 154000
#
# Current train loss: 2.191924571990967
# 1 a of being in a camera
# ..................................................
# GT Captions
# 1 <BOS> terrorists are posing for the camera
# ..................................................
# Current validation loss: 4.73174524307251
# Saved 154000
#
# Iteration 155000
#
# Current train loss: 2.7582907676696777
# 1 a man is a a guitar
# ..................................................
# GT Captions
# 1 <BOS> a man playing  the guitar
# ..................................................
# Current validation loss: 2.1810801029205322
#
# Iteration 156000
#
# Current train loss: 5.908755779266357
# 1 a are a
# ..................................................
# GT Captions
# 1 <BOS> toys assembled together on a table
# ..................................................
# Current validation loss: 6.00732946395874
# Saved 156000
#
# Iteration 157000
#
# Current train loss: 7.372568130493164
# 1 a cartoon of is
# ..................................................
# GT Captions
# 1 <BOS> a cartoon graphic illustrating the ways of the animal kingdom and prehistoric man
# ..................................................
# Current validation loss: 6.918203830718994
#
# Iteration 158000
#
# Current train loss: 8.168546676635742
# 1 a man of a
# ..................................................
# GT Captions
# 1 <BOS> a video about basketball players playing basketball
# ..................................................
# Current validation loss: 3.671980619430542
# Saved 158000
#
# Iteration 159000
#
# Current train loss: 2.8808705806732178
# 1 a man is interviewed
# ..................................................
# GT Captions
# 1 <BOS> a man being interviewed
# ..................................................
# Current validation loss: 1.7725279331207275
#
# Iteration 160000
#
# Current train loss: 4.803574562072754
# 1 a is being on the water
# ..................................................
# GT Captions
# 1 <BOS> water is running in the hill
# ..................................................
# Current validation loss: 3.2610762119293213
# Saved 160000
#
# Iteration 161000
#
# Current train loss: 2.368412971496582
# 1 a woman is a blue shirt is talking a animal
# ..................................................
# GT Captions
# 1 <BOS> a person in a blue shirt is petting an animal
# ..................................................
# Current validation loss: 2.6658518314361572
#
# Iteration 162000
#
# Current train loss: 2.357541084289551
# 1 a man is on a table
# ..................................................
# GT Captions
# 1 <BOS> a man sitting at a desk is wearing a dark grey suit coat and tie is in front of a large screen
# ..................................................
# Current validation loss: 3.0633394718170166
# Saved 162000
#
# Iteration 163000
#
# Current train loss: 5.79129695892334
# 1 a man is playing with a cat
# ..................................................
# GT Captions
# 1 <BOS> a dog is playing with a kid and popping bubbles
# ..................................................
# Current validation loss: 3.8151702880859375
#
# Iteration 164000
#
# Current train loss: 6.544004917144775
# 1 a are a video in a video
# ..................................................
# GT Captions
# 1 <BOS> people select their players for a game of mario cart
# ..................................................
# Current validation loss: 5.789939880371094
# Saved 164000
#
# Iteration 165000
#
# Current train loss: 3.652078866958618
# 1 a man is talking a car car of
# ..................................................
# GT Captions
# 1 <BOS> a man is in a parking lot
# ..................................................
# Current validation loss: 2.7574732303619385
#
# Iteration 166000
#
# Current train loss: 6.185354709625244
# 1 a woman is to a camera
# ..................................................
# GT Captions
# 1 <BOS> a woman speaks to the camera on a vlog
# ..................................................
# Current validation loss: 2.4354095458984375
# Saved 166000
#
# Iteration 167000
#
# Current train loss: 7.313177108764648
# 1 a men birds at man are a
# ..................................................
# GT Captions
# 1 <BOS> four angry looking young people in punk style clothing are preparing to use hover boards while another man s hover board loses power
# ..................................................
# Current validation loss: 7.293092727661133
#
# Iteration 168000
#
# Current train loss: 4.4435343742370605
# 1 a man is on the street
# ..................................................
# GT Captions
# 1 <BOS> animated whale go through the ocean
# ..................................................
# Current validation loss: 5.416445732116699
# Saved 168000
#
# Iteration 169000
#
# Current train loss: 3.4038233757019043
# 1 a boy is on man
# ..................................................
# GT Captions
# 1 <BOS> little boy flying a kite
# ..................................................
# Current validation loss: 5.538187503814697
#
# Iteration 170000
#
# Current train loss: 3.7366442680358887
# 1 a person is making how to make a
# ..................................................
# GT Captions
# 1 <BOS> a person is demonstrating how to cut leeks on a chopping board and use them for soup
# ..................................................
# Current validation loss: 4.405457496643066
# Saved 170000
#
# Iteration 171000
#
# Current train loss: 2.1342856884002686
# 1 a man is talking about stage stage
# ..................................................
# GT Captions
# 1 <BOS> a man is talking on the mic in a show
# ..................................................
# Current validation loss: 2.3209638595581055
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-2da0ffaf5447> in <module>()
# ----> 1 train()
#
# <ipython-input-16-7a0726b3bb2b> in train()
#     123                                                                             caption:caps,
#     124                                                                             caption_mask:caps_mask,
# --> 125                                                                             dropout_prob:0.5})
#     126
#     127                 if i%1000 == 0:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Testing

# %%
def test():
    with tf.Graph().as_default():
        learning_rate = 0.00001
        video,caption,caption_mask,output_logits,loss,dropout_prob = build_model()
        optim = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(loss)
        ckpt_file = './ckpt_v5/model_58000.ckpt.meta'
        saver = tf.train.Saver()
        with tf.Session() as sess:
            if ckpt_file:
                saver_ = tf.train.import_meta_graph(ckpt_file)
                saver_.restore(sess,'./ckpt_v5/model_58000.ckpt')
                print ("Restored model")
            else:
                sess.run(tf.initialize_all_variables())
            while(1):
                vid,caption_GT,_,current_batch_vids = fetch_data_batch_val(1)
                caps,caps_mask = convert_caption(['<BOS>'],word2id,30)

                for i in range(30):
                    o_l = sess.run(output_logits,feed_dict={video:vid,
                                                            caption:caps,
                                                            caption_mask:caps_mask,
                                                            dropout_prob:1.0})
                    out_logits = o_l.reshape([batch_size,n_steps-1,vocab_size])
                    output_captions = np.argmax(out_logits,2)
                    caps[0][i+1] = output_captions[0][i]
                    print_in_english(caps)
                    if id2word[output_captions[0][i]] == '<EOS>':
                        break
                print ('............................\nGT Caption:\n')
                print_in_english(caption_GT)
                play_video = input('Should I play the video? ')
                if play_video.lower() == 'y':
                    playVideo(current_batch_vids)
                test_again = input('Want another test run? ')
                if test_again.lower() == 'n':
                    break
test()
# Out:
# Network config:
# N_Steps: 30
# Hidden_dim:500
# Frame_dim:2048
# Batch_size:1
# Vocab_size:29325
#
# Created weights
# Video_input: (1, 59, 500)
# Video_output: (1, 59, 500)
# Caption_input: (1, 59, 1000)
# Caption_output: (1, 59, 500)
# INFO:tensorflow:Restoring parameters from ./ckpt_v5/model_58000.ckpt
# Restored model
# 1 <BOS> a
# ..................................................
# 1 <BOS> a person
# ..................................................
# 1 <BOS> a person is
# ..................................................
# 1 <BOS> a person is cooking
# ..................................................
# 1 <BOS> a person is cooking a
# ..................................................
# 1 <BOS> a person is cooking a dish
# ..................................................
# 1 <BOS> a person is cooking a dish in
# ..................................................
# 1 <BOS> a person is cooking a dish in a
# ..................................................
# 1 <BOS> a person is cooking a dish in a pot
# ..................................................
# 1 <BOS> a person is cooking a dish in a pot
# ..................................................
# ............................
# GT Caption:
#
# 1 <BOS> a woman shows a mixing technique
# ..................................................
# Should I play the video? n
# Want another test run? y
# 1 <BOS> a
# ..................................................
# 1 <BOS> a woman
# ..................................................
# 1 <BOS> a woman is
# ..................................................
# 1 <BOS> a woman is talking
# ..................................................
# 1 <BOS> a woman is talking about
# ..................................................
# 1 <BOS> a woman is talking about her
# ..................................................
# 1 <BOS> a woman is talking about her hair
# ..................................................
# 1 <BOS> a woman is talking about her hair
# ..................................................
# ............................
# GT Caption:
#
# 1 <BOS> the food is placed in the plate while the woman on white sofa is talking
# ..................................................
# Should I play the video? n
# Want another test run? y
# 1 <BOS> a
# ..................................................
# 1 <BOS> a man
# ..................................................
# 1 <BOS> a man is
# ..................................................
# 1 <BOS> a man is talking
# ..................................................
# 1 <BOS> a man is talking about
# ..................................................
# 1 <BOS> a man is talking about a
# ..................................................
# 1 <BOS> a man is talking about a video
# ..................................................
# 1 <BOS> a man is talking about a video game
# ..................................................
# 1 <BOS> a man is talking about a video game
# ..................................................
# ............................
# GT Caption:
#
# 1 <BOS> a diglett fights a voltorb in an epic pokemon battle
# ..................................................
# Should I play the video? n
# Want another test run? y
# 1 <BOS> a
# ..................................................
# 1 <BOS> a man
# ..................................................
# 1 <BOS> a man and
# ..................................................
# 1 <BOS> a man and a
# ..................................................
# 1 <BOS> a man and a woman
# ..................................................
# 1 <BOS> a man and a woman are
# ..................................................
# 1 <BOS> a man and a woman are walking
# ..................................................
# 1 <BOS> a man and a woman are walking in
# ..................................................
# 1 <BOS> a man and a woman are walking in a
# ..................................................
# 1 <BOS> a man and a woman are walking in a park
# ..................................................
# 1 <BOS> a man and a woman are walking in a park
# ..................................................
# ............................
# GT Caption:
#
# 1 <BOS> a group of children are playing in the forest while a man sings
# ..................................................
# Should I play the video? n
# Want another test run? y
# 1 <BOS> a
# ..................................................
# 1 <BOS> a man
# ..................................................
# 1 <BOS> a man is
# ..................................................
# 1 <BOS> a man is talking
# ..................................................
# 1 <BOS> a man is talking about
# ..................................................
# 1 <BOS> a man is talking about a
# ..................................................
# 1 <BOS> a man is talking about a dog
# ..................................................
# 1 <BOS> a man is talking about a dog
# ..................................................
# ............................
# GT Caption:
#
# 1 <BOS> a large spider is crawling on a white wall
# ..................................................
# Should I play the video? n
# Want another test run? y
# 1 <BOS> a
# ..................................................
# 1 <BOS> a man
# ..................................................
# 1 <BOS> a man is
# ..................................................
# 1 <BOS> a man is talking
# ..................................................
# 1 <BOS> a man is talking to
# ..................................................
# 1 <BOS> a man is talking to a
# ..................................................
# 1 <BOS> a man is talking to a woman
# ..................................................
# 1 <BOS> a man is talking to a woman
# ..................................................
# ............................
# GT Caption:
#
# 1 <BOS> youtubers react to shia labouf the musical
# ..................................................
# Should I play the video? n
# Want another test run? y
# 1 <BOS> a
# ..................................................
# 1 <BOS> a woman
# ..................................................
# 1 <BOS> a woman is
# ..................................................
# 1 <BOS> a woman is singing
# ..................................................
# 1 <BOS> a woman is singing
# ..................................................
# ............................
# GT Caption:
#
# 1 <BOS> an older man sheds tears of joy while a young woman sings a song to a large audience
# ..................................................
# Should I play the video? n
# Want another test run? n
